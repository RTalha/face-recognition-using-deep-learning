# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# Out:
# /home/rana/anaconda3/envs/conaenv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
'''
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
    '''

# %%
#model.save_weights("face_model.h5")
model.load_weights("face_model.h5")
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 50, 50, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# lrn_1 (Lambda)                  (None, 24, 24, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 24, 24, 64)   4160        lrn_1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 24, 24, 64)   256         conv2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 26, 26, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 24, 24, 192)  110784      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 24, 24, 192)  768         conv3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 192)  0           bn3[0][0]
# __________________________________________________________________________________________________
# lrn_2 (Lambda)                  (None, 24, 24, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 26, 26, 192)  0           lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 12, 12, 96)   18528       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 12, 12, 16)   3088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn1 (BatchNorm (None, 12, 12, 16)   64          inception_3a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 96)   0           inception_3a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 12, 16)   0           inception_3a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 192)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 14, 14, 96)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 16)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_conv (Conv2D) (None, 5, 5, 32)     6176        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv2 (Conv2D) (None, 12, 12, 32)   12832       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_bn (BatchNorm (None, 5, 5, 32)     128         inception_3a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_conv (Conv2D)  (None, 12, 12, 64)   12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn2 (BatchNorm (None, 12, 12, 32)   128         inception_3a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 32)     0           inception_3a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 128)  0           inception_3a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 12, 32)   0           inception_3a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 12, 12, 32)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 64)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  zero_padding2d_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# power2_3b (Lambda)              (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv1 (Conv2D) (None, 12, 12, 96)   24672       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv1 (Conv2D) (None, 12, 12, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 256)    0           power2_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3b_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_3b (Lambda)               (None, 4, 4, 256)    0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 96)   0           inception_3b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 12, 32)   0           inception_3b_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_3b (Lambda)                (None, 4, 4, 256)    0           mult9_3b[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 14, 14, 96)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 16, 16, 32)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_conv (Conv2D) (None, 4, 4, 64)     16448       sqrt_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv2 (Conv2D) (None, 12, 12, 64)   51264       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_bn (BatchNorm (None, 4, 4, 64)     256         inception_3b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_conv (Conv2D)  (None, 12, 12, 64)   16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn2 (BatchNorm (None, 12, 12, 64)   256         inception_3b_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 64)     0           inception_3b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 12, 128)  0           inception_3b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 12, 64)   0           inception_3b_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 12, 12, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 12, 12, 64)   0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 320)  0           activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  zero_padding2d_10[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv1 (Conv2D) (None, 12, 12, 128)  41088       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv1 (Conv2D) (None, 12, 12, 32)   10272       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn1 (BatchNorm (None, 12, 12, 128)  512         inception_3c_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3c_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           inception_3c_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 32)   0           inception_3c_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 14, 14, 128)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 32)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv2 (Conv2D) (None, 6, 6, 256)    295168      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn2 (BatchNorm (None, 6, 6, 256)    1024        inception_3c_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_3c_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 320)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 6, 6, 256)    0           inception_3c_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6, 6, 64)     0           inception_3c_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 6, 6, 320)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 6, 6, 640)    0           activation_17[0][0]
#                                                                  activation_19[0][0]
#                                                                  zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# power2_4a (Lambda)              (None, 6, 6, 640)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv1 (Conv2D) (None, 6, 6, 96)     61536       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv1 (Conv2D) (None, 6, 6, 32)     20512       concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 640)    0           power2_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn1 (BatchNorm (None, 6, 6, 96)     384         inception_4a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn1 (BatchNorm (None, 6, 6, 32)     128         inception_4a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_4a (Lambda)               (None, 2, 2, 640)    0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 6, 6, 96)     0           inception_4a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 32)     0           inception_4a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_4a (Lambda)                (None, 2, 2, 640)    0           mult9_4a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 8, 8, 96)     0           activation_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 10, 10, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_conv (Conv2D) (None, 2, 2, 128)    82048       sqrt_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv2 (Conv2D) (None, 6, 6, 192)    166080      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_bn (BatchNorm (None, 2, 2, 128)    512         inception_4a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_conv (Conv2D)  (None, 6, 6, 256)    164096      concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn2 (BatchNorm (None, 6, 6, 192)    768         inception_4a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_4a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 128)    0           inception_4a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 6, 6, 256)    1024        inception_4a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 192)    0           inception_4a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 64)     0           inception_4a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 6, 6, 128)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6, 6, 640)    0           activation_21[0][0]
#                                                                  activation_23[0][0]
#                                                                  zero_padding2d_16[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv1 (Conv2D) (None, 6, 6, 160)    102560      concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv1 (Conv2D) (None, 6, 6, 64)     41024       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn1 (BatchNorm (None, 6, 6, 160)    640         inception_4e_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn1 (BatchNorm (None, 6, 6, 64)     256         inception_4e_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 6, 160)    0           inception_4e_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 6, 6, 64)     0           inception_4e_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 8, 8, 160)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 10, 10, 64)   0           activation_28[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv2 (Conv2D) (None, 3, 3, 256)    368896      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv2 (Conv2D) (None, 3, 3, 128)    204928      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn2 (BatchNorm (None, 3, 3, 256)    1024        inception_4e_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn2 (BatchNorm (None, 3, 3, 128)    512         inception_4e_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 640)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           inception_4e_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 3, 3, 128)    0           inception_4e_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 3, 3, 640)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 3, 1024)   0           activation_27[0][0]
#                                                                  activation_29[0][0]
#                                                                  zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# power2_5a (Lambda)              (None, 3, 3, 1024)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv1 (Conv2D) (None, 3, 3, 96)     98400       concatenate_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 1024)   0           power2_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_5a (Lambda)               (None, 1, 1, 1024)   0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, 3, 96)     0           inception_5a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_5a (Lambda)                (None, 1, 1, 1024)   0           mult9_5a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 5, 5, 96)     0           activation_30[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_conv (Conv2D) (None, 1, 1, 96)     98400       sqrt_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_conv (Conv2D)  (None, 3, 3, 256)    262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 1, 96)     0           inception_5a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, 3, 384)    0           inception_5a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 3, 3, 96)     0           activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, 3, 256)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3, 3, 736)    0           activation_31[0][0]
#                                                                  zero_padding2d_21[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv1 (Conv2D) (None, 3, 3, 96)     70752       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, 3, 96)     0           inception_5b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 736)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 5, 5, 96)     0           activation_34[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_conv (Conv2D) (None, 1, 1, 96)     70752       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_conv (Conv2D)  (None, 3, 3, 256)    188672      concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 1, 96)     0           inception_5b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, 3, 384)    0           inception_5b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 3, 3, 96)     0           activation_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, 3, 256)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 3, 3, 736)    0           activation_35[0][0]
#                                                                  zero_padding2d_23[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 736)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 736)          0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, 128)          94336       flatten_1[0][0]
# __________________________________________________________________________________________________
# norm_layer (Lambda)             (None, 128)          0           dense_layer[0][0]
# ==================================================================================================
# Total params: 3,743,280
# Trainable params: 3,733,968
# Non-trainable params: 9,312
# __________________________________________________________________________________________________

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        if input_name.find("talha") !=-1:
            input_name="talha"
        if input_name.find("zeeshan") !=-1:
            input_name="zeeshan"
        if input_name.find("hadi") !=-1:
            input_name="hadi"
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        #if person_name.find("talha") !=-1:
         #   person_name="talha"
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)
    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    
    vc = cv2.VideoCapture("final.mp4")
    
    cv2.namedWindow("Face Recognizer")
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while True:
        _, frame = vc.read()
        img = frame
        print(frame)
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %%
embadings=create_input_image_embeddings()

# %%
print(embadings)
# Out:
# {'talha83': array([[-2.23117471e-02,  1.21554919e-02,  4.48547862e-02,
#          7.46603981e-02,  4.68490981e-02,  2.12877646e-01,
#          5.08776587e-03, -8.29283372e-02,  7.27197826e-02,
#         -1.44435436e-01, -6.50395220e-03,  2.00698301e-02,
#          2.38236487e-02, -7.14273602e-02,  3.24793812e-03,
#          1.86755341e-02, -1.19110063e-01,  1.15044508e-02,
#         -8.51297677e-02,  4.65318635e-02,  1.93285927e-01,
#         -1.15140751e-01,  6.13812124e-03,  1.22866735e-01,
#          7.38771483e-02, -1.01857208e-01, -2.05356732e-01,
#         -1.98346809e-01, -6.21831417e-02,  5.70132881e-02,
#          2.07435071e-01,  4.13794741e-02, -4.91285212e-02,
#          7.36091509e-02,  1.10084414e-01,  1.52638525e-01,
#         -2.06252392e-02, -1.63433496e-02, -6.90015266e-03,
#         -1.11155383e-01,  7.97451884e-02, -5.55799566e-02,
#          5.59204929e-02, -2.04557329e-02,  2.69802529e-02,
#         -1.09601222e-01,  1.18156530e-01,  6.26379997e-03,
#         -7.69241154e-02,  2.24857479e-02, -1.04129322e-01,
#         -1.68323860e-01,  1.15474969e-01, -8.74107517e-03,
#          1.29644319e-01,  9.61381868e-02, -9.74879712e-02,
#          1.24725446e-01, -7.09707141e-02, -1.32910565e-01,
#         -1.11872867e-01,  1.03371434e-01,  1.17073692e-01,
#         -2.37928867e-01,  1.33379281e-01,  9.37855393e-02,
#          8.96533858e-03, -5.70503250e-02, -1.77869931e-01,
#          5.09226508e-02, -5.93030200e-05,  6.30655214e-02,
#         -1.01620302e-01, -6.41510040e-02,  1.30951582e-02,
#          2.06675213e-02,  5.52249234e-03, -3.28255408e-02,
#          4.20992449e-02,  9.53878164e-02, -5.43150082e-02,
#          1.91636924e-02, -3.05540487e-02, -2.80880537e-02,
#         -1.15691416e-01,  7.03843161e-02,  1.28687136e-02,
#          3.80362733e-03, -5.26550785e-02,  6.63522705e-02,
#          1.30670682e-01, -1.31655157e-01,  2.69721597e-02,
#         -3.31752119e-03, -4.44783680e-02,  6.20139912e-02,
#         -7.70436749e-02,  8.29939395e-02, -4.08081636e-02,
#          8.82263258e-02,  4.90703136e-02, -5.85870743e-02,
#         -1.20613605e-01, -3.20768096e-02,  1.00997956e-02,
#          1.53331369e-01, -4.61672852e-03, -2.44844798e-02,
#         -5.69876358e-02,  1.97859257e-02, -1.14745334e-01,
#          5.36220102e-03, -7.36943036e-02, -7.01110289e-02,
#          9.97119471e-02,  9.98293459e-02, -4.75873612e-02,
#          2.22314820e-02,  1.64627638e-02,  1.60556048e-01,
#          7.27685019e-02, -4.55375239e-02,  1.70286316e-02,
#          0.10739341, -0.00615491, -0.05772799, -0.19090544,  0.13388935,
#         -0.0035003 ,  0.04617184, -0.10204656, -0.05360961,  0.01374878,
#         -0.00984113, -0.00562792, -0.02103696,  0.02055722,  0.05577108,
#         -0.05481142,  0.06066127, -0.05020406, -0.03417945, -0.08292849,
#          0.02400259, -0.03741441,  0.01773131, -0.07231645,  0.11450001,
#          0.13909596, -0.06466115,  0.02155616,  0.01921841, -0.00915375,
#          0.06685622, -0.05940274,  0.10810441, -0.03525686,  0.05330976,
#          0.05352132, -0.05265067, -0.13863371, -0.0656798 ,  0.05380963,
#          0.15466024,  0.06772324, -0.05732707,  0.02667472,  0.03821908,
#         -0.13652605,  0.01676408, -0.05030664, -0.07288181,  0.14151873,
#          0.04432191, -0.06545205, -0.00815384,  0.04797442,  0.153551  ,
#          0.10240993, -0.03555693,  0.03652526,  0.01843505, -0.00424572,
#          0.14550811,  0.14893156, -0.00648658]], dtype=float32)}

# %%
recognize_faces_in_cam(embadings)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Euclidean distance from hadi52 is 0.6610812
# Euclidean distance from hadi61 is 0.48250827
# Euclidean distance from talha77 is 0.7032755
# Euclidean distance from hadi43 is 0.763266
# Euclidean distance from hadi97 is 0.68943447
# Euclidean distance from hadi70 is 0.939419
# Euclidean distance from hadi49 is 0.7014884
# Euclidean distance from talha91 is 0.7456948
# Euclidean distance from talha64 is 0.728609
# Euclidean distance from hadi57 is 0.5301285
# Euclidean distance from talha93 is 0.74540925
# Euclidean distance from talha41 is 0.74044603
# Euclidean distance from hadi15 is 0.72487485
# Euclidean distance from zeeshan6 is 0.85905033
# Euclidean distance from talha47 is 0.7470248
# Euclidean distance from talha65 is 0.7579875
# Euclidean distance from hadi55 is 0.6598299
# Euclidean distance from talha100 is 0.7803659
# Euclidean distance from zeeshan5 is 0.8051009
# Euclidean distance from zeeshan24 is 0.80536574
# Euclidean distance from zeeshan12 is 0.8707753
# Euclidean distance from hadi66 is 0.72459376
# Euclidean distance from hadi85 is 0.7247206
# Euclidean distance from talha60 is 0.75893867
# Euclidean distance from talha48 is 0.6832132
# Euclidean distance from talha72 is 0.71734464
# Euclidean distance from hadi12 is 0.7853581
# Euclidean distance from talha35 is 0.7178694
# Euclidean distance from talha75 is 0.7522225
# Euclidean distance from hadi14 is 0.70712906
# Euclidean distance from hadi99 is 0.7021966
# Euclidean distance from zeeshan3 is 0.7691601
# Euclidean distance from talha62 is 0.777824
# Euclidean distance from hadi46 is 0.67103565
# Euclidean distance from hadi64 is 0.61694586
# Euclidean distance from hadi13 is 0.70269936
# Euclidean distance from talha43 is 0.7186398
# Euclidean distance from hadi7 is 0.82946426
# Euclidean distance from talha33 is 0.76787704
# Euclidean distance from hadi27 is 0.5652475
# Euclidean distance from talha49 is 0.7591504
# Euclidean distance from talha26 is 0.7991599
# Euclidean distance from talha37 is 0.7824593
# Euclidean distance from hadi82 is 0.811194
# Euclidean distance from hadi31 is 0.4909703
# Euclidean distance from hadi93 is 0.7442303
# Euclidean distance from hadi65 is 0.66725004
# Euclidean distance from hadi17 is 0.8000183
# Euclidean distance from talha76 is 0.7258904
# Euclidean distance from talha27 is 0.7426031
# Euclidean distance from hadi62 is 0.55720603
# Euclidean distance from hadi63 is 0.6179094
# Euclidean distance from talha87 is 0.6274512
# Euclidean distance from hadi20 is 0.67091787
# Euclidean distance from hadi9 is 0.7470958
# Euclidean distance from hadi53 is 0.66692245
# Euclidean distance from hadi56 is 0.629574
# Euclidean distance from zeeshan20 is 0.96439195
# Euclidean distance from talha82 is 0.64530355
# Euclidean distance from hadi3 is 0.7225449
# Euclidean distance from hadi30 is 0.5375671
# Euclidean distance from hadi91 is 0.7192658
# Euclidean distance from talha97 is 0.84763044
# Euclidean distance from zeeshan18 is 0.9233644
# Euclidean distance from hadi73 is 0.8430732
# Euclidean distance from talha85 is 0.63576025
# Euclidean distance from zeeshan10 is 0.95450026
# Euclidean distance from talha74 is 0.7319131
# Euclidean distance from talha34 is 0.75443274
# Euclidean distance from hadi22 is 0.6678796
# Euclidean distance from talha81 is 0.6200418
# Euclidean distance from talha57 is 0.75453717
# Euclidean distance from talha89 is 0.69728655
# Euclidean distance from hadi54 is 0.66139287
# Euclidean distance from talha68 is 0.78730375
# Euclidean distance from zeeshan8 is 0.9567192
# Euclidean distance from talha59 is 0.8649475
# Euclidean distance from hadi29 is 0.51656026
# Euclidean distance from hadi81 is 0.86359245
# Euclidean distance from talha31 is 0.76612186
# Euclidean distance from hadi89 is 0.6039435
# Euclidean distance from zeeshan15 is 1.0066841
# Euclidean distance from talha70 is 0.6778686
# Euclidean distance from zeeshan2 is 0.9239859
# Euclidean distance from hadi94 is 0.7542844
# Euclidean distance from talha80 is 0.69871014
# Euclidean distance from hadi39 is 0.69788057
# Euclidean distance from hadi41 is 0.66398484
# Euclidean distance from talha79 is 0.65297294
# Euclidean distance from hadi78 is 0.8936979
# Euclidean distance from talha66 is 0.7309371
# Euclidean distance from zeeshan13 is 1.2101533
# Euclidean distance from zeeshan21 is 1.009161
# Euclidean distance from talha25 is 0.8462789
# Euclidean distance from hadi19 is 0.6909548
# Euclidean distance from talha32 is 0.8025831
# Euclidean distance from hadi48 is 0.6551613
# Euclidean distance from hadi33 is 0.60521877
# Euclidean distance from hadi40 is 0.6394534
# Euclidean distance from hadi36 is 0.6083512
# Euclidean distance from hadi83 is 0.897438
# Euclidean distance from talha58 is 0.8267973
# Euclidean distance from hadi2 is 0.67552984
# Euclidean distance from talha95 is 0.80982673
# Euclidean distance from hadi96 is 0.70015407
# Euclidean distance from hadi92 is 0.65497655
# Euclidean distance from hadi68 is 0.74037164
# Euclidean distance from zeeshan14 is 1.0152339
# Euclidean distance from hadi95 is 0.57284665
# Euclidean distance from talha94 is 0.80550414
# Euclidean distance from hadi4 is 0.8281208
# Euclidean distance from hadi45 is 0.7654124
# Euclidean distance from hadi88 is 0.63039017
# Euclidean distance from hadi72 is 0.8232951
# Euclidean distance from zeeshan11 is 0.94377893
# Euclidean distance from hadi16 is 0.7572009
# Euclidean distance from talha71 is 0.6507829
# Euclidean distance from talha40 is 0.80192035
# Euclidean distance from talha92 is 0.6898153
# Euclidean distance from hadi90 is 0.6541065
# Euclidean distance from talha42 is 0.75142866
# Euclidean distance from talha39 is 0.8280404
# Euclidean distance from talha53 is 0.79668844
# Euclidean distance from talha88 is 0.62569207
# Euclidean distance from talha69 is 0.6669362
# Euclidean distance from hadi74 is 0.83835346
# Euclidean distance from zeeshan7 is 0.89215714
# Euclidean distance from zeeshan19 is 0.9275539
# Euclidean distance from talha13 is 0.8080922
# Euclidean distance from hadi42 is 0.6690854
# Euclidean distance from hadi34 is 0.65791875
# Euclidean distance from talha99 is 0.7690408
# Euclidean distance from talha51 is 0.8066267
# Euclidean distance from talha45 is 0.74189794
# Euclidean distance from zeeshan17 is 1.0043178
# Euclidean distance from zeeshan16 is 0.8686389
# Euclidean distance from zeeshan9 is 0.9190353
# Euclidean distance from talha54 is 0.83235747
# Euclidean distance from talha30 is 0.71136343
# Euclidean distance from talha46 is 0.80396944
# Euclidean distance from hadi79 is 0.8919195
# Euclidean distance from hadi87 is 0.6824354
# Euclidean distance from talha78 is 0.61154217
# Euclidean distance from hadi98 is 0.67939436
# Euclidean distance from hadi25 is 0.5536235
# Euclidean distance from zeeshan4 is 0.7536848
# Euclidean distance from hadi76 is 0.7815029
# Euclidean distance from hadi11 is 0.8069756
# Euclidean distance from hadi23 is 0.5281269
# Euclidean distance from hadi100 is 0.659598
# Euclidean distance from talha83 is 0.6115606
# Euclidean distance from talha63 is 0.7962959
# Euclidean distance from hadi86 is 0.60881114
# Euclidean distance from talha84 is 0.7196677
# Euclidean distance from talha73 is 0.6742674
# Euclidean distance from talha38 is 0.81964445
# Euclidean distance from talha86 is 0.62964237
# Euclidean distance from hadi84 is 0.7606645
# Euclidean distance from talha36 is 0.75157166
# Euclidean distance from hadi32 is 0.55463845
# Euclidean distance from hadi6 is 0.8283719
# Euclidean distance from talha90 is 0.7355782
# Euclidean distance from hadi35 is 0.6418227
# Euclidean distance from talha56 is 0.63898903
# Euclidean distance from hadi10 is 0.7642562
# Euclidean distance from hadi28 is 0.60115767
# Euclidean distance from hadi44 is 0.6703
# Euclidean distance from hadi24 is 0.5703214
# Euclidean distance from talha29 is 0.79769665
# Euclidean distance from talha52 is 0.70606655
# Euclidean distance from hadi69 is 0.8813758
# Euclidean distance from hadi71 is 0.8554737
# Euclidean distance from talha50 is 0.7664132
# Euclidean distance from talha96 is 0.820424
# Euclidean distance from hadi47 is 0.74563074
# Euclidean distance from hadi60 is 0.49467728
# Euclidean distance from zeeshan22 is 0.9043263
# Euclidean distance from talha28 is 0.76230156
# Euclidean distance from hadi67 is 0.72057503
# Euclidean distance from talha67 is 0.7617472
# Euclidean distance from hadi75 is 0.78539824
# Euclidean distance from hadi37 is 0.66151106
# Euclidean distance from hadi8 is 0.7562242
# Euclidean distance from talha61 is 0.81316847
# Euclidean distance from hadi58 is 0.62420434
# Euclidean distance from zeeshan25 is 0.85723305
# Euclidean distance from hadi59 is 0.63296986
# Euclidean distance from hadi77 is 0.78495735
# Euclidean distance from talha44 is 0.7265706
# Euclidean distance from talha55 is 0.7725649
# Euclidean distance from hadi21 is 0.6361194
# Euclidean distance from zeeshan23 is 0.8997053
# Euclidean distance from hadi5 is 0.84688467
# Euclidean distance from hadi50 is 0.72823703
# Euclidean distance from hadi38 is 0.69474137
# Euclidean distance from talha98 is 0.7825106
# Euclidean distance from hadi80 is 0.8325072
# Euclidean distance from hadi51 is 0.65532166
# Euclidean distance from hadi18 is 0.6561042
# Euclidean distance from hadi26 is 0.4762329
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Euclidean distance from hadi52 is 0.6124955
# Euclidean distance from hadi61 is 0.4669388
# Euclidean distance from talha77 is 0.78809243
# Euclidean distance from hadi43 is 0.7034642
# Euclidean distance from hadi97 is 0.6765336
# Euclidean distance from hadi70 is 0.88156784
# Euclidean distance from hadi49 is 0.64703643
# Euclidean distance from talha91 is 0.7615394
# Euclidean distance from talha64 is 0.79468906
# Euclidean distance from hadi57 is 0.48049748
# Euclidean distance from talha93 is 0.7791551
# Euclidean distance from talha41 is 0.7132823
# Euclidean distance from hadi15 is 0.65357
# Euclidean distance from zeeshan6 is 0.88574827
# Euclidean distance from talha47 is 0.7150734
# Euclidean distance from talha65 is 0.8252036
# Euclidean distance from hadi55 is 0.61278194
# Euclidean distance from talha100 is 0.8038447
# Euclidean distance from zeeshan5 is 0.81308293
# Euclidean distance from zeeshan24 is 0.8078576
# Euclidean distance from zeeshan12 is 0.88084173
# Euclidean distance from hadi66 is 0.66236174
# Euclidean distance from hadi85 is 0.731151
# Euclidean distance from talha60 is 0.7764824
# Euclidean distance from talha48 is 0.6467189
# Euclidean distance from talha72 is 0.77022666
# Euclidean distance from hadi12 is 0.7046261
# Euclidean distance from talha35 is 0.7610117
# Euclidean distance from talha75 is 0.8465855
# Euclidean distance from hadi14 is 0.6365742
# Euclidean distance from hadi99 is 0.65991443
# Euclidean distance from zeeshan3 is 0.7695987
# Euclidean distance from talha62 is 0.82040197
# Euclidean distance from hadi46 is 0.6291035
# Euclidean distance from hadi64 is 0.5845872
# Euclidean distance from hadi13 is 0.63395256
# Euclidean distance from talha43 is 0.71887183
# Euclidean distance from hadi7 is 0.7410151
# Euclidean distance from talha33 is 0.7975938
# Euclidean distance from hadi27 is 0.5233756
# Euclidean distance from talha49 is 0.74893296
# Euclidean distance from talha26 is 0.7959911
# Euclidean distance from talha37 is 0.8001615
# Euclidean distance from hadi82 is 0.76539916
# Euclidean distance from hadi31 is 0.45742515
# Euclidean distance from hadi93 is 0.73756593
# Euclidean distance from hadi65 is 0.61892945
# Euclidean distance from hadi17 is 0.7374404
# Euclidean distance from talha76 is 0.8290915
# Euclidean distance from talha27 is 0.77539504
# Euclidean distance from hadi62 is 0.5077538
# Euclidean distance from hadi63 is 0.60658324
# Euclidean distance from talha87 is 0.65976757
# Euclidean distance from hadi20 is 0.6289189
# Euclidean distance from hadi9 is 0.6595923
# Euclidean distance from hadi53 is 0.6169785
# Euclidean distance from hadi56 is 0.5587209
# Euclidean distance from zeeshan20 is 0.89095104
# Euclidean distance from talha82 is 0.7253836
# Euclidean distance from hadi3 is 0.6519745
# Euclidean distance from hadi30 is 0.482202
# Euclidean distance from hadi91 is 0.70269674
# Euclidean distance from talha97 is 0.86502415
# Euclidean distance from zeeshan18 is 0.89454573
# Euclidean distance from hadi73 is 0.7850962
# Euclidean distance from talha85 is 0.6727515
# Euclidean distance from zeeshan10 is 1.0011451
# Euclidean distance from talha74 is 0.82449573
# Euclidean distance from talha34 is 0.8021618
# Euclidean distance from hadi22 is 0.61586004
# Euclidean distance from talha81 is 0.6719981
# Euclidean distance from talha57 is 0.75017285
# Euclidean distance from talha89 is 0.73917085
# Euclidean distance from hadi54 is 0.6168098
# Euclidean distance from talha68 is 0.7992143
# Euclidean distance from zeeshan8 is 0.981862
# Euclidean distance from talha59 is 0.8929826
# Euclidean distance from hadi29 is 0.4653536
# Euclidean distance from hadi81 is 0.80097634
# Euclidean distance from talha31 is 0.7910848
# Euclidean distance from hadi89 is 0.6139633
# Euclidean distance from zeeshan15 is 1.0105174
# Euclidean distance from talha70 is 0.7185043
# Euclidean distance from zeeshan2 is 0.8998122
# Euclidean distance from hadi94 is 0.7478979
# Euclidean distance from talha80 is 0.78372365
# Euclidean distance from hadi39 is 0.6442149
# Euclidean distance from hadi41 is 0.61902803
# Euclidean distance from talha79 is 0.7314075
# Euclidean distance from hadi78 is 0.8268825
# Euclidean distance from talha66 is 0.79693645
# Euclidean distance from zeeshan13 is 1.2590967
# Euclidean distance from zeeshan21 is 0.96563816
# Euclidean distance from talha25 is 0.85270244
# Euclidean distance from hadi19 is 0.65391934
# Euclidean distance from talha32 is 0.82971734
# Euclidean distance from hadi48 is 0.59894246
# Euclidean distance from hadi33 is 0.53276354
# Euclidean distance from hadi40 is 0.60566384
# Euclidean distance from hadi36 is 0.5463593
# Euclidean distance from hadi83 is 0.84810853
# Euclidean distance from talha58 is 0.83922654
# Euclidean distance from hadi2 is 0.6153305
# Euclidean distance from talha95 is 0.84111977
# Euclidean distance from hadi96 is 0.6957016
# Euclidean distance from hadi92 is 0.66715086
# Euclidean distance from hadi68 is 0.66467816
# Euclidean distance from zeeshan14 is 1.0181779
# Euclidean distance from hadi95 is 0.60491526
# Euclidean distance from talha94 is 0.8402026
# Euclidean distance from hadi4 is 0.7418993
# Euclidean distance from hadi45 is 0.7210136
# Euclidean distance from hadi88 is 0.66663533
# Euclidean distance from hadi72 is 0.77846295
# Euclidean distance from zeeshan11 is 0.98143804
# Euclidean distance from hadi16 is 0.6905353
# Euclidean distance from talha71 is 0.7356272
# Euclidean distance from talha40 is 0.80712545
# Euclidean distance from talha92 is 0.6905053
# Euclidean distance from hadi90 is 0.6711949
# Euclidean distance from talha42 is 0.74332213
# Euclidean distance from talha39 is 0.85151416
# Euclidean distance from talha53 is 0.80664027
# Euclidean distance from talha88 is 0.66462606
# Euclidean distance from talha69 is 0.7157932
# Euclidean distance from hadi74 is 0.7940151
# Euclidean distance from zeeshan7 is 0.9361489
# Euclidean distance from zeeshan19 is 0.8949429
# Euclidean distance from talha13 is 0.7883223
# Euclidean distance from hadi42 is 0.6312009
# Euclidean distance from hadi34 is 0.60204464
# Euclidean distance from talha99 is 0.81928736
# Euclidean distance from talha51 is 0.78875595
# Euclidean distance from talha45 is 0.7378549
# Euclidean distance from zeeshan17 is 0.9813389
# Euclidean distance from zeeshan16 is 0.80382234
# Euclidean distance from zeeshan9 is 0.9638802
# Euclidean distance from talha54 is 0.85833836
# Euclidean distance from talha30 is 0.7350784
# Euclidean distance from talha46 is 0.7888064
# Euclidean distance from hadi79 is 0.8211415
# Euclidean distance from hadi87 is 0.6985579
# Euclidean distance from talha78 is 0.6983142
# Euclidean distance from hadi98 is 0.6792846
# Euclidean distance from hadi25 is 0.50260824
# Euclidean distance from zeeshan4 is 0.75198776
# Euclidean distance from hadi76 is 0.720686
# Euclidean distance from hadi11 is 0.7188219
# Euclidean distance from hadi23 is 0.52488256
# Euclidean distance from hadi100 is 0.6546776
# Euclidean distance from talha83 is 0.67502314
# Euclidean distance from talha63 is 0.85504216
# Euclidean distance from hadi86 is 0.6095617
# Euclidean distance from talha84 is 0.7528484
# Euclidean distance from talha73 is 0.76314384
# Euclidean distance from talha38 is 0.84382236
# Euclidean distance from talha86 is 0.66287756
# Euclidean distance from hadi84 is 0.7594602
# Euclidean distance from talha36 is 0.7746985
# Euclidean distance from hadi32 is 0.48079193
# Euclidean distance from hadi6 is 0.74545884
# Euclidean distance from talha90 is 0.7269465
# Euclidean distance from hadi35 is 0.5612649
# Euclidean distance from talha56 is 0.67008406
# Euclidean distance from hadi10 is 0.6797153
# Euclidean distance from hadi28 is 0.5437918
# Euclidean distance from hadi44 is 0.6231847
# Euclidean distance from hadi24 is 0.5374688
# Euclidean distance from talha29 is 0.80006385
# Euclidean distance from talha52 is 0.6957448
# Euclidean distance from hadi69 is 0.836574
# Euclidean distance from hadi71 is 0.8196403
# Euclidean distance from talha50 is 0.7540569
# Euclidean distance from talha96 is 0.835679
# Euclidean distance from hadi47 is 0.71146196
# Euclidean distance from hadi60 is 0.47340328
# Euclidean distance from zeeshan22 is 0.86771816
# Euclidean distance from talha28 is 0.77453434
# Euclidean distance from hadi67 is 0.6574454
# Euclidean distance from talha67 is 0.8345608
# Euclidean distance from hadi75 is 0.7293934
# Euclidean distance from hadi37 is 0.62034583
# Euclidean distance from hadi8 is 0.66619104
# Euclidean distance from talha61 is 0.8514153
# Euclidean distance from hadi58 is 0.57275087
# Euclidean distance from zeeshan25 is 0.8343422
# Euclidean distance from hadi59 is 0.5913846
# Euclidean distance from hadi77 is 0.7288486
# Euclidean distance from talha44 is 0.68428594
# Euclidean distance from talha55 is 0.77441466
# Euclidean distance from hadi21 is 0.6078952
# Euclidean distance from zeeshan23 is 0.9038075
# Euclidean distance from hadi5 is 0.76026404
# Euclidean distance from hadi50 is 0.67212385
# Euclidean distance from hadi38 is 0.6400605
# Euclidean distance from talha98 is 0.81258416
# Euclidean distance from hadi80 is 0.7788236
# Euclidean distance from hadi51 is 0.5954904
# Euclidean distance from hadi18 is 0.61763793
# Euclidean distance from hadi26 is 0.43674412
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Euclidean distance from hadi52 is 0.66665196
# Euclidean distance from hadi61 is 0.56015337
# Euclidean distance from talha77 is 0.8239063
# Euclidean distance from hadi43 is 0.7375475
# Euclidean distance from hadi97 is 0.67004853
# Euclidean distance from hadi70 is 0.812532
# Euclidean distance from hadi49 is 0.71480995
# Euclidean distance from talha91 is 0.7144726
# Euclidean distance from talha64 is 0.78747165
# Euclidean distance from hadi57 is 0.5067012
# Euclidean distance from talha93 is 0.76841897
# Euclidean distance from talha41 is 0.7015612
# Euclidean distance from hadi15 is 0.6835108
# Euclidean distance from zeeshan6 is 0.8590508
# Euclidean distance from talha47 is 0.70883393
# Euclidean distance from talha65 is 0.81424594
# Euclidean distance from hadi55 is 0.6118304
# Euclidean distance from talha100 is 0.77998334
# Euclidean distance from zeeshan5 is 0.7745734
# Euclidean distance from zeeshan24 is 0.72277445
# Euclidean distance from zeeshan12 is 0.81170714
# Euclidean distance from hadi66 is 0.63946617
# Euclidean distance from hadi85 is 0.7829648
# Euclidean distance from talha60 is 0.73301154
# Euclidean distance from talha48 is 0.59817326
# Euclidean distance from talha72 is 0.71151763
# Euclidean distance from hadi12 is 0.73324007
# Euclidean distance from talha35 is 0.7640699
# Euclidean distance from talha75 is 0.8885297
# Euclidean distance from hadi14 is 0.6866243
# Euclidean distance from hadi99 is 0.6053355
# Euclidean distance from zeeshan3 is 0.7063568
# Euclidean distance from talha62 is 0.793084
# Euclidean distance from hadi46 is 0.6857545
# Euclidean distance from hadi64 is 0.62135845
# Euclidean distance from hadi13 is 0.6870596
# Euclidean distance from talha43 is 0.7127101
# Euclidean distance from hadi7 is 0.77797455
# Euclidean distance from talha33 is 0.7734614
# Euclidean distance from hadi27 is 0.5062968
# Euclidean distance from talha49 is 0.74221057
# Euclidean distance from talha26 is 0.7490541
# Euclidean distance from talha37 is 0.7888199
# Euclidean distance from hadi82 is 0.7773381
# Euclidean distance from hadi31 is 0.51151556
# Euclidean distance from hadi93 is 0.79181355
# Euclidean distance from hadi65 is 0.62949675
# Euclidean distance from hadi17 is 0.7750225
# Euclidean distance from talha76 is 0.86541235
# Euclidean distance from talha27 is 0.7517518
# Euclidean distance from hadi62 is 0.53677714
# Euclidean distance from hadi63 is 0.6472103
# Euclidean distance from talha87 is 0.65208733
# Euclidean distance from hadi20 is 0.670676
# Euclidean distance from hadi9 is 0.680133
# Euclidean distance from hadi53 is 0.6504669
# Euclidean distance from hadi56 is 0.5647682
# Euclidean distance from zeeshan20 is 0.8102136
# Euclidean distance from talha82 is 0.7466238
# Euclidean distance from hadi3 is 0.71273494
# Euclidean distance from hadi30 is 0.52073973
# Euclidean distance from hadi91 is 0.75097173
# Euclidean distance from talha97 is 0.8214415
# Euclidean distance from zeeshan18 is 0.7790754
# Euclidean distance from hadi73 is 0.7078948
# Euclidean distance from talha85 is 0.6887047
# Euclidean distance from zeeshan10 is 0.95367914
# Euclidean distance from talha74 is 0.81263906
# Euclidean distance from talha34 is 0.8177825
# Euclidean distance from hadi22 is 0.6091277
# Euclidean distance from talha81 is 0.6863604
# Euclidean distance from talha57 is 0.7070669
# Euclidean distance from talha89 is 0.7472201
# Euclidean distance from hadi54 is 0.6332671
# Euclidean distance from talha68 is 0.7139816
# Euclidean distance from zeeshan8 is 0.95550156
# Euclidean distance from talha59 is 0.8746875
# Euclidean distance from hadi29 is 0.5049442
# Euclidean distance from hadi81 is 0.80470246
# Euclidean distance from talha31 is 0.7713491
# Euclidean distance from hadi89 is 0.59088147
# Euclidean distance from zeeshan15 is 0.95724654
# Euclidean distance from talha70 is 0.6825306
# Euclidean distance from zeeshan2 is 0.7895579
# Euclidean distance from hadi94 is 0.8044395
# Euclidean distance from talha80 is 0.7928928
# Euclidean distance from hadi39 is 0.6594829
# Euclidean distance from hadi41 is 0.65112543
# Euclidean distance from talha79 is 0.7406623
# Euclidean distance from hadi78 is 0.7488783
# Euclidean distance from talha66 is 0.7861656
# Euclidean distance from zeeshan13 is 1.1903057
# Euclidean distance from zeeshan21 is 0.93611646
# Euclidean distance from talha25 is 0.8230726
# Euclidean distance from hadi19 is 0.7105435
# Euclidean distance from talha32 is 0.8284455
# Euclidean distance from hadi48 is 0.6634685
# Euclidean distance from hadi33 is 0.54590875
# Euclidean distance from hadi40 is 0.6039377
# Euclidean distance from hadi36 is 0.5624855
# Euclidean distance from hadi83 is 0.8360159
# Euclidean distance from talha58 is 0.7844431
# Euclidean distance from hadi2 is 0.6772381
# Euclidean distance from talha95 is 0.82001
# Euclidean distance from hadi96 is 0.6871496
# Euclidean distance from hadi92 is 0.7008801
# Euclidean distance from hadi68 is 0.6648812
# Euclidean distance from zeeshan14 is 0.9966944
# Euclidean distance from hadi95 is 0.7001524
# Euclidean distance from talha94 is 0.8066791
# Euclidean distance from hadi4 is 0.78824824
# Euclidean distance from hadi45 is 0.7909651
# Euclidean distance from hadi88 is 0.711783
# Euclidean distance from hadi72 is 0.69361895
# Euclidean distance from zeeshan11 is 0.9230091
# Euclidean distance from hadi16 is 0.7232941
# Euclidean distance from talha71 is 0.73357356
# Euclidean distance from talha40 is 0.7683546
# Euclidean distance from talha92 is 0.6416759
# Euclidean distance from hadi90 is 0.71291447
# Euclidean distance from talha42 is 0.71223706
# Euclidean distance from talha39 is 0.8370953
# Euclidean distance from talha53 is 0.7734777
# Euclidean distance from talha88 is 0.65673906
# Euclidean distance from talha69 is 0.68439436
# Euclidean distance from hadi74 is 0.72424287
# Euclidean distance from zeeshan7 is 0.9048915
# Euclidean distance from zeeshan19 is 0.78983355
# Euclidean distance from talha13 is 0.7753997
# Euclidean distance from hadi42 is 0.67958295
# Euclidean distance from hadi34 is 0.5969095
# Euclidean distance from talha99 is 0.79926616
# Euclidean distance from talha51 is 0.7676246
# Euclidean distance from talha45 is 0.73205274
# Euclidean distance from zeeshan17 is 0.8438253
# Euclidean distance from zeeshan16 is 0.7023383
# Euclidean distance from zeeshan9 is 0.93779224
# Euclidean distance from talha54 is 0.82831377
# Euclidean distance from talha30 is 0.70052165
# Euclidean distance from talha46 is 0.7730648
# Euclidean distance from hadi79 is 0.77287465
# Euclidean distance from hadi87 is 0.74370795
# Euclidean distance from talha78 is 0.71972597
# Euclidean distance from hadi98 is 0.71004546
# Euclidean distance from hadi25 is 0.54757196
# Euclidean distance from zeeshan4 is 0.6683004
# Euclidean distance from hadi76 is 0.640851
# Euclidean distance from hadi11 is 0.73115987
# Euclidean distance from hadi23 is 0.60835564
# Euclidean distance from hadi100 is 0.6348517
# Euclidean distance from talha83 is 0.6872285
# Euclidean distance from talha63 is 0.823225
# Euclidean distance from hadi86 is 0.60058594
# Euclidean distance from talha84 is 0.7094335
# Euclidean distance from talha73 is 0.76838094
# Euclidean distance from talha38 is 0.82251585
# Euclidean distance from talha86 is 0.67633194
# Euclidean distance from hadi84 is 0.83759433
# Euclidean distance from talha36 is 0.75324994
# Euclidean distance from hadi32 is 0.48272237
# Euclidean distance from hadi6 is 0.7911974
# Euclidean distance from talha90 is 0.6710132
# Euclidean distance from hadi35 is 0.5745885
# Euclidean distance from talha56 is 0.67158675
# Euclidean distance from hadi10 is 0.67197746
# Euclidean distance from hadi28 is 0.52763325
# Euclidean distance from hadi44 is 0.6723261
# Euclidean distance from hadi24 is 0.57909536
# Euclidean distance from talha29 is 0.7697479
# Euclidean distance from talha52 is 0.66999036
# Euclidean distance from hadi69 is 0.75475955
# Euclidean distance from hadi71 is 0.7236362
# Euclidean distance from talha50 is 0.73791885
# Euclidean distance from talha96 is 0.82802945
# Euclidean distance from hadi47 is 0.78359985
# Euclidean distance from hadi60 is 0.47380906
# Euclidean distance from zeeshan22 is 0.75413203
# Euclidean distance from talha28 is 0.73135513
# Euclidean distance from hadi67 is 0.6375705
# Euclidean distance from talha67 is 0.83116627
# Euclidean distance from hadi75 is 0.6505979
# Euclidean distance from hadi37 is 0.6279558
# Euclidean distance from hadi8 is 0.67684263
# Euclidean distance from talha61 is 0.8281582
# Euclidean distance from hadi58 is 0.5672871
# Euclidean distance from zeeshan25 is 0.77138793
# Euclidean distance from hadi59 is 0.57783407
# Euclidean distance from hadi77 is 0.6632796
# Euclidean distance from talha44 is 0.6745592
# Euclidean distance from talha55 is 0.74629945
# Euclidean distance from hadi21 is 0.6566053
# Euclidean distance from zeeshan23 is 0.86385787
# Euclidean distance from hadi5 is 0.81386817
# Euclidean distance from hadi50 is 0.7115723
# Euclidean distance from hadi38 is 0.6573936
# Euclidean distance from talha98 is 0.7900697
# Euclidean distance from hadi80 is 0.8005932
# Euclidean distance from hadi51 is 0.6483864
# Euclidean distance from hadi18 is 0.6710837
# Euclidean distance from hadi26 is 0.47412696
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Euclidean distance from hadi52 is 0.72381884
# Euclidean distance from hadi61 is 0.6641944
# Euclidean distance from talha77 is 0.9099317
# Euclidean distance from hadi43 is 0.7680374
# Euclidean distance from hadi97 is 0.72959304
# Euclidean distance from hadi70 is 1.0241019
# Euclidean distance from hadi49 is 0.67703277
# Euclidean distance from talha91 is 0.97969466
# Euclidean distance from talha64 is 0.9171667
# Euclidean distance from hadi57 is 0.79311496
# Euclidean distance from talha93 is 0.9225555
# Euclidean distance from talha41 is 0.9457775
# Euclidean distance from hadi15 is 0.81592387
# Euclidean distance from zeeshan6 is 1.1466049
# Euclidean distance from talha47 is 0.9199518
# Euclidean distance from talha65 is 0.9259822
# Euclidean distance from hadi55 is 0.871278
# Euclidean distance from talha100 is 1.0038527
# Euclidean distance from zeeshan5 is 1.1057513
# Euclidean distance from zeeshan24 is 1.0607026
# Euclidean distance from zeeshan12 is 1.1347929
# Euclidean distance from hadi66 is 0.89131343
# Euclidean distance from hadi85 is 0.66996187
# Euclidean distance from talha60 is 0.9898719
# Euclidean distance from talha48 is 0.9542201
# Euclidean distance from talha72 is 0.9792786
# Euclidean distance from hadi12 is 0.85940707
# Euclidean distance from talha35 is 0.9836209
# Euclidean distance from talha75 is 0.94606626
# Euclidean distance from hadi14 is 0.7749869
# Euclidean distance from hadi99 is 0.86871845
# Euclidean distance from zeeshan3 is 1.0675308
# Euclidean distance from talha62 is 0.9978211
# Euclidean distance from hadi46 is 0.70078593
# Euclidean distance from hadi64 is 0.8178839
# Euclidean distance from hadi13 is 0.77015305
# Euclidean distance from talha43 is 0.9813985
# Euclidean distance from hadi7 is 0.8533054
# Euclidean distance from talha33 is 1.044918
# Euclidean distance from hadi27 is 0.8421327
# Euclidean distance from talha49 is 0.87891847
# Euclidean distance from talha26 is 1.0281683
# Euclidean distance from talha37 is 1.0059692
# Euclidean distance from hadi82 is 0.77315557
# Euclidean distance from hadi31 is 0.77199155
# Euclidean distance from hadi93 is 0.67317176
# Euclidean distance from hadi65 is 0.84012127
# Euclidean distance from hadi17 is 0.8321112
# Euclidean distance from talha76 is 0.874592
# Euclidean distance from talha27 is 1.0418545
# Euclidean distance from hadi62 is 0.79973924
# Euclidean distance from hadi63 is 0.79262745
# Euclidean distance from talha87 is 0.82549703
# Euclidean distance from hadi20 is 0.79412925
# Euclidean distance from hadi9 is 0.8374111
# Euclidean distance from hadi53 is 0.7936118
# Euclidean distance from hadi56 is 0.85432506
# Euclidean distance from zeeshan20 is 1.2093444
# Euclidean distance from talha82 is 0.82415915
# Euclidean distance from hadi3 is 0.7356997
# Euclidean distance from hadi30 is 0.7994139
# Euclidean distance from hadi91 is 0.69824505
# Euclidean distance from talha97 is 1.0369797
# Euclidean distance from zeeshan18 is 1.1626296
# Euclidean distance from hadi73 is 1.0185586
# Euclidean distance from talha85 is 0.81996316
# Euclidean distance from zeeshan10 is 1.1970413
# Euclidean distance from talha74 is 0.936862
# Euclidean distance from talha34 is 1.0226147
# Euclidean distance from hadi22 is 0.88892424
# Euclidean distance from talha81 is 0.85504085
# Euclidean distance from talha57 is 0.94645125
# Euclidean distance from talha89 is 0.819729
# Euclidean distance from hadi54 is 0.8220756
# Euclidean distance from talha68 is 1.0632559
# Euclidean distance from zeeshan8 is 1.1498914
# Euclidean distance from talha59 is 1.0303348
# Euclidean distance from hadi29 is 0.7654991
# Euclidean distance from hadi81 is 0.84099066
# Euclidean distance from talha31 is 1.0405896
# Euclidean distance from hadi89 is 0.7844013
# Euclidean distance from zeeshan15 is 0.97075146
# Euclidean distance from talha70 is 0.8986195
# Euclidean distance from zeeshan2 is 1.1593536
# Euclidean distance from hadi94 is 0.666987
# Euclidean distance from talha80 is 0.8953663
# Euclidean distance from hadi39 is 0.8177398
# Euclidean distance from hadi41 is 0.7973112
# Euclidean distance from talha79 is 0.8564443
# Euclidean distance from hadi78 is 1.0222237
# Euclidean distance from talha66 is 0.93623704
# Euclidean distance from zeeshan13 is 1.3834157
# Euclidean distance from zeeshan21 is 1.0706353
# Euclidean distance from talha25 is 1.0635213
# Euclidean distance from hadi19 is 0.75140756
# Euclidean distance from talha32 is 1.0183647
# Euclidean distance from hadi48 is 0.68944913
# Euclidean distance from hadi33 is 0.8494087
# Euclidean distance from hadi40 is 0.8230955
# Euclidean distance from hadi36 is 0.8176548
# Euclidean distance from hadi83 is 0.82632834
# Euclidean distance from talha58 is 1.0461504
# Euclidean distance from hadi2 is 0.7667592
# Euclidean distance from talha95 is 0.98980933
# Euclidean distance from hadi96 is 0.7565508
# Euclidean distance from hadi92 is 0.7130396
# Euclidean distance from hadi68 is 0.84299856
# Euclidean distance from zeeshan14 is 0.99490476
# Euclidean distance from hadi95 is 0.51729393
# Euclidean distance from talha94 is 0.9813532
# Euclidean distance from hadi4 is 0.7973427
# Euclidean distance from hadi45 is 0.6797239
# Euclidean distance from hadi88 is 0.67365205
# Euclidean distance from hadi72 is 1.0189375
# Euclidean distance from zeeshan11 is 1.2047238
# Euclidean distance from hadi16 is 0.81112343
# Euclidean distance from talha71 is 0.90239567
# Euclidean distance from talha40 is 1.0619521
# Euclidean distance from talha92 is 0.9521381
# Euclidean distance from hadi90 is 0.6726265
# Euclidean distance from talha42 is 1.0095721
# Euclidean distance from talha39 is 1.0699756
# Euclidean distance from talha53 is 0.99610525
# Euclidean distance from talha88 is 0.8617922
# Euclidean distance from talha69 is 0.90198624
# Euclidean distance from hadi74 is 1.0193826
# Euclidean distance from zeeshan7 is 1.1589969
# Euclidean distance from zeeshan19 is 1.1805456
# Euclidean distance from talha13 is 0.96274483
# Euclidean distance from hadi42 is 0.7151748
# Euclidean distance from hadi34 is 0.87886906
# Euclidean distance from talha99 is 0.9652542
# Euclidean distance from talha51 is 0.9587142
# Euclidean distance from talha45 is 0.9116587
# Euclidean distance from zeeshan17 is 1.2269595
# Euclidean distance from zeeshan16 is 1.0171095
# Euclidean distance from zeeshan9 is 1.1320418
# Euclidean distance from talha54 is 0.9595799
# Euclidean distance from talha30 is 0.998804
# Euclidean distance from talha46 is 0.97356576
# Euclidean distance from hadi79 is 0.953574
# Euclidean distance from hadi87 is 0.65217555
# Euclidean distance from talha78 is 0.8347362
# Euclidean distance from hadi98 is 0.66431415
# Euclidean distance from hadi25 is 0.72420996
# Euclidean distance from zeeshan4 is 1.0909061
# Euclidean distance from hadi76 is 0.9419299
# Euclidean distance from hadi11 is 0.9062374
# Euclidean distance from hadi23 is 0.6591223
# Euclidean distance from hadi100 is 0.78912014
# Euclidean distance from talha83 is 0.78703713
# Euclidean distance from talha63 is 1.0019879
# Euclidean distance from hadi86 is 0.7839776
# Euclidean distance from talha84 is 0.97442997
# Euclidean distance from talha73 is 0.8821156
# Euclidean distance from talha38 is 1.0673404
# Euclidean distance from talha86 is 0.77426267
# Euclidean distance from hadi84 is 0.61327404
# Euclidean distance from talha36 is 1.0175986
# Euclidean distance from hadi32 is 0.8308117
# Euclidean distance from hadi6 is 0.8175035
# Euclidean distance from talha90 is 0.9710227
# Euclidean distance from hadi35 is 0.8444486
# Euclidean distance from talha56 is 0.8756704
# Euclidean distance from hadi10 is 0.862417
# Euclidean distance from hadi28 is 0.87892586
# Euclidean distance from hadi44 is 0.71540076
# Euclidean distance from hadi24 is 0.7256487
# Euclidean distance from talha29 is 1.0461316
# Euclidean distance from talha52 is 0.88176775
# Euclidean distance from hadi69 is 1.0240263
# Euclidean distance from hadi71 is 0.9981492
# Euclidean distance from talha50 is 0.86877984
# Euclidean distance from talha96 is 0.87083125
# Euclidean distance from hadi47 is 0.6559458
# Euclidean distance from hadi60 is 0.80102885
# Euclidean distance from zeeshan22 is 1.075851
# Euclidean distance from talha28 is 1.0317932
# Euclidean distance from hadi67 is 0.8633057
# Euclidean distance from talha67 is 0.9100807
# Euclidean distance from hadi75 is 0.9326657
# Euclidean distance from hadi37 is 0.846478
# Euclidean distance from hadi8 is 0.85494506
# Euclidean distance from talha61 is 1.0369681
# Euclidean distance from hadi58 is 0.841513
# Euclidean distance from zeeshan25 is 1.1311592
# Euclidean distance from hadi59 is 0.8451809
# Euclidean distance from hadi77 is 0.9380913
# Euclidean distance from talha44 is 0.9556496
# Euclidean distance from talha55 is 0.9478909
# Euclidean distance from hadi21 is 0.7560504
# Euclidean distance from zeeshan23 is 1.077533
# Euclidean distance from hadi5 is 0.7942715
# Euclidean distance from hadi50 is 0.73244166
# Euclidean distance from hadi38 is 0.85891956
# Euclidean distance from talha98 is 0.99567837
# Euclidean distance from hadi80 is 0.7982717
# Euclidean distance from hadi51 is 0.71699387
# Euclidean distance from hadi18 is 0.7664398
# Euclidean distance from hadi26 is 0.7330408
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
print(embadings)
# Out:
# {'talha': array([[-0.0073184 ,  0.09710307,  0.0739255 ,  0.11024836, -0.0082513 ,
#          0.22730763, -0.03609352, -0.1092994 , -0.00503406, -0.12323545,
#          0.03472897,  0.04012552, -0.05259926, -0.12375665,  0.00100145,
#         -0.07222142, -0.09855896,  0.01389686, -0.01694784,  0.09409071,
#          0.02618501, -0.05971131,  0.05271079,  0.09491225,  0.03111317,
#         -0.05501433, -0.09313961, -0.08532983, -0.03517501, -0.04391602,
#          0.15657681, -0.01020222, -0.02827452,  0.09286058,  0.08549304,
#          0.13100778,  0.03313581,  0.02452001, -0.01868108, -0.07393228,
#          0.09790815, -0.1055328 ,  0.01377283, -0.04376515, -0.10019749,
#         -0.10772042,  0.1249359 ,  0.00569132, -0.09719499,  0.14246824,
#         -0.04673095, -0.01141298,  0.02895137,  0.03836491,  0.11139525,
#          0.04345188, -0.05985874,  0.05647569, -0.07785788, -0.08414223,
#         -0.15585114,  0.08655155,  0.17352681, -0.26946387,  0.15902837,
#          0.06028251,  0.06410053, -0.15149558, -0.23967208,  0.18980367,
#         -0.03415499,  0.03233135, -0.05536614,  0.15068701,  0.0736541 ,
#         -0.08012679,  0.0482787 ,  0.0031368 ,  0.04280226,  0.02995962,
#         -0.10319868, -0.00392478,  0.03441723, -0.02593393, -0.01880442,
#         -0.01666806, -0.03644225,  0.03178228, -0.00599333,  0.11427212,
#          0.15417556, -0.12532283,  0.08396473, -0.00939384,  0.02711979,
#         -0.0593764 ,  0.00552022,  0.10160551, -0.02815444,  0.02904682,
#         -0.04754853,  0.06303149, -0.1133315 , -0.00182651,  0.06993005,
#          0.17328566,  0.1020574 , -0.01533027, -0.00483475,  0.02701764,
#         -0.07666896,  0.07345172,  0.03162717,  0.02812394,  0.06318509,
#         -0.04626176,  0.07461008, -0.03231183,  0.11062101,  0.16537815,
#          0.08818649, -0.08295809,  0.03642387, -0.0019465 ,  0.04229669,
#          0.09921317,  0.1836576 ,  0.03470652]], dtype=float32)}

# %%
import cv2
cam = cv2.VideoCapture("/home/rana/mypython/FaceRecognition/Face-recognition-using-deep-learning-master/hadi.mp4")

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
count +=1
print(count)
while(True):
    ret, img = cam.read()
    #print(ret)
    #print(img)
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    print(faces)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        print(count)
        # Save the captured image into the datasets folder
        cv2.imwrite("images/hadi" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 100: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()
# Out:
# 1
# [[148  93 231 231]]
# 2
# [[148  91 234 234]]
# 3
# [[149  89 234 234]]
# 4
# [[150  88 235 235]]
# 5
# [[152  88 234 234]]
# 6
# [[152  85 238 238]]
# 7
# [[154  83 240 240]]
# 8
# [[155  83 242 242]]
# 9
# [[154  79 247 247]]
# 10
# [[154  83 239 239]]
# 11
# [[157  85 236 236]]
# 12
# [[158  84 241 241]]
# 13
# [[158  83 243 243]]
# 14
# [[159  79 248 248]]
# 15
# [[162  79 244 244]]
# 16
# [[167  81 241 241]]
# 17
# [[169  84 241 241]]
# 18
# [[173  81 243 243]]
# 19
# [[174  79 248 248]]
# 20
# [[177  79 248 248]]
# 21
# [[178  76 255 255]]
# 22
# [[184  82 245 245]]
# 23
# [[185  78 250 250]]
# 24
# [[187  78 252 252]]
# 25
# [[195  80 247 247]]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
    identities = []
    for (x, y, w, h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h

           
            
    face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
    identity = recognize_face(face_image, input_embeddings, model)
    #print(identify)
            
            

    if identity is not None:
        img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
        cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
    cv2.imwrite("rana.jpg",img)
    cv2.destroyAllWindows()

# %%
recognize_faces_in_cam(input_embeddings)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !conda list
# Out:
# # packages in environment at /home/rana/anaconda3/envs/conaenv:
# #
# # Name                    Version                   Build  Channel
# absl-py                   0.4.1                    py35_0
# alabaster                 0.7.10           py35h6fb19ab_0
# anaconda                  custom           py35h104c396_0
# anaconda-client           1.6.14                   py35_0
# anaconda-project          0.8.2            py35h7d62c80_0
# asn1crypto                0.24.0                   py35_0
# astor                     0.7.1                    py35_0
# astroid                   1.6.3                    py35_0
# astropy                   3.0.2            py35h3010b51_1
# attrs                     18.1.0                   py35_0
# babel                     2.5.3                    py35_0
# backcall                  0.1.0                    py35_0
# backports                 1.0              py35hd471ac7_1
# backports.shutil_get_terminal_size 1.0.0            py35h40844db_2
# backports.weakref         1.0rc1                   py35_0
# beautifulsoup4            4.6.0            py35h442a8c9_1
# bitarray                  0.8.1            py35h14c3975_1
# bkcharts                  0.2              py35he4f7e30_0
# blas                      1.0                         mkl
# blaze                     0.11.3           py35ha2c9137_0
# bleach                    1.5.0                    py35_0
# blosc                     1.14.3               hdbcaa40_0
# bokeh                     0.12.16                  py35_0
# boto                      2.48.0           py35h2cfd601_1
# bottleneck                1.2.1            py35he1b16f1_0
# bzip2                     1.0.6                h14c3975_5
# ca-certificates           2019.1.23                     0
# cairo                     1.14.12              h7636065_2
# certifi                   2018.8.24                py35_1
# cffi                      1.11.5           py35h9745a5d_0
# chardet                   3.0.4            py35hb6e9ddf_1
# click                     6.7              py35h353a69f_0
# cloudpickle               0.5.3                    py35_0
# clyent                    1.2.2            py35h491ffcb_1
# colorama                  0.3.9            py35h81e2b6c_0
# contextlib2               0.5.5            py35h6690dba_0
# cryptography              2.2.2            py35h14c3975_0
# cudatoolkit               7.5                           2
# cudnn                     5.1                           0
# curl                      7.60.0               h84994c4_0
# cycler                    0.10.0           py35hc4d5149_0
# cython                    0.28.2           py35h14c3975_0
# cytoolz                   0.9.0.1          py35h14c3975_0
# dask                      0.17.5                   py35_0
# dask-core                 0.17.5                   py35_0
# datashape                 0.5.4            py35h5b068ae_0
# dbus                      1.13.2               h714fa37_1
# decorator                 4.3.0                    py35_0
# distributed               1.21.8                   py35_0
# docutils                  0.14             py35hd11081d_0
# entrypoints               0.2.3            py35h48174a2_2
# et_xmlfile                1.0.1            py35hde8d43e_0
# expat                     2.2.5                he0dffb1_0
# fastcache                 1.0.2            py35h14c3975_2
# filelock                  3.0.4                    py35_0
# flask                     1.0.2                    py35_1
# flask-cors                3.0.4                    py35_0
# fontconfig                2.12.6               h49f89f6_0
# freetype                  2.8                  hab7d2ae_1
# gast                      0.2.0                    py35_0
# get_terminal_size         1.0.0                haa9412d_0
# gevent                    1.3.0            py35h14c3975_0
# glib                      2.56.1               h000015b_0
# glob2                     0.6              py35hff66265_0
# gmp                       6.1.2                h6c8ec71_1
# gmpy2                     2.0.8            py35hd0a1c9a_2
# graphite2                 1.3.11               h16798f4_2
# greenlet                  0.4.13           py35h14c3975_0
# grpcio                    1.12.1           py35hdbcaa40_0
# gst-plugins-base          1.14.0               hbbd80ab_1
# gstreamer                 1.14.0               hb453b48_1
# h5py                      2.7.1            py35ha1f6525_2
# harfbuzz                  1.7.6                h5f0a787_1
# hdf5                      1.10.2               hba1933b_1
# heapdict                  1.0.0                    py35_2
# html5lib                  0.9999999                py35_0
# icu                       58.2                 h9c2bf20_1
# idna                      2.6              py35h8605a33_1
# imageio                   2.3.0                    py35_0
# imagesize                 1.0.0                    py35_0
# intel-openmp              2018.0.0                      8
# ipykernel                 4.8.2                    py35_0
# ipython                   6.4.0                    py35_0
# ipython_genutils          0.2.0            py35hc9e07d0_0
# ipywidgets                7.2.1                    py35_0
# isort                     4.3.4                    py35_0
# itsdangerous              0.24             py35h7c46880_1
# jbig                      2.1                  hdba287a_0
# jdcal                     1.4                      py35_0
# jedi                      0.12.0                   py35_1
# jinja2                    2.10             py35h480ab6d_0
# jpeg                      9b                   h024ee3a_2
# jsonschema                2.6.0            py35h4395190_0
# jupyter                   1.0.0                    py35_4
# jupyter_client            5.2.3                    py35_0
# jupyter_console           5.2.0            py35h4044a63_1
# jupyter_core              4.4.0            py35ha89e94b_0
# jupyterlab                0.32.1                   py35_0
# jupyterlab_launcher       0.10.5                   py35_0
# keras                     2.2.4                    pypi_0    pypi
# keras-applications        1.0.7                    pypi_0    pypi
# keras-preprocessing       1.0.9                    pypi_0    pypi
# kiwisolver                1.0.1            py35hcb1117a_0
# lazy-object-proxy         1.3.1            py35h4c720c6_0
# libcurl                   7.60.0               h1ad7b7a_0
# libedit                   3.1.20170329         h6b74fdf_2
# libffi                    3.2.1                hd88cf55_4
# libgcc                    7.2.0                h69d50b8_2
# libgcc-ng                 8.2.0                hdf63c60_1
# libgfortran-ng            7.2.0                hdf63c60_3
# libpng                    1.6.34               hb9fc6fc_0
# libprotobuf               3.6.0                hdbcaa40_0
# libsodium                 1.0.16               h1bed415_0
# libssh2                   1.8.0                h9cfc8f7_4
# libstdcxx-ng              7.2.0                hdf63c60_3
# libtiff                   4.0.9                he85c1e1_1
# libtool                   2.4.6                h544aabb_3
# libxcb                    1.13                 h1bed415_1
# libxml2                   2.9.8                h26e45fe_1
# libxslt                   1.1.32               h1312cb7_0
# llvmlite                  0.23.1           py35hdbcaa40_0
# locket                    0.2.0            py35h170bc82_1
# lxml                      4.2.1            py35h23eabaa_0
# lzo                       2.10                 h49e0be7_2
# markdown                  2.6.11                   py35_0
# markupsafe                1.0              py35h4f4fcf6_1
# matplotlib                2.2.2            py35h0e671d2_1
# mccabe                    0.6.1            py35hd8c1f23_1
# mistune                   0.8.3            py35h14c3975_1
# mkl                       2018.0.2                      1
# mkl-service               1.1.2            py35h0fc7090_4
# mkl_fft                   1.0.1            py35h3010b51_0
# mkl_random                1.0.1            py35h629b387_0
# more-itertools            4.1.0                    py35_0
# mpc                       1.0.3                hec55b23_5
# mpfr                      3.1.5                h11a74b3_2
# mpmath                    1.0.0            py35h7ce6e34_2
# msgpack-python            0.5.6            py35h6bb024c_0
# multipledispatch          0.5.0                    py35_0
# nbconvert                 5.3.1            py35hc5194e3_0
# nbformat                  4.4.0            py35h12e6e07_0
# ncurses                   6.1                  hf484d3e_0
# networkx                  2.1                      py35_0
# nltk                      3.3.0                    py35_0
# nose                      1.3.7            py35hdc64897_2
# notebook                  5.5.0                    py35_0
# numba                     0.38.0           py35h637b7d7_0
# numexpr                   2.6.5            py35h7bf3b9c_0
# numpy                     1.12.1           py35hca0bb5e_1
# numpy-base                1.14.3           py35hdbf6ddf_0
# numpydoc                  0.8.0                    py35_0
# odo                       0.5.1            py35h102315f_0
# olefile                   0.45.1                   py35_0
# opencv-python             4.1.0.25                 pypi_0    pypi
# openpyxl                  2.5.3                    py35_0
# openssl                   1.0.2r               h7b6447c_0
# packaging                 17.1                     py35_0
# pandas                    0.23.0           py35h637b7d7_0
# pandoc                    1.19.2.1             hea2e7c5_1
# pandocfilters             1.4.2            py35h1565a15_1
# pango                     1.41.0               hd475d92_0
# parso                     0.2.0                    py35_0
# partd                     0.3.8            py35h68187f2_0
# patchelf                  0.9                  hf79760b_2
# path.py                   11.0.1                   py35_0
# pathlib2                  2.3.2                    py35_0
# patsy                     0.5.0                    py35_0
# pcre                      8.42                 h439df22_0
# pep8                      1.7.1                    py35_0
# pexpect                   4.5.0                    py35_0
# pickleshare               0.7.4            py35hd57304d_0
# pillow                    5.1.0            py35h3deb7b8_0
# pip                       19.0.3                   pypi_0    pypi
# pixman                    0.34.0               hceecf20_3
# pkginfo                   1.4.2                    py35_1
# pluggy                    0.6.0            py35hb428803_0
# ply                       3.11                     py35_0
# prompt_toolkit            1.0.15           py35hc09de7a_0
# protobuf                  3.7.1                    pypi_0    pypi
# psutil                    5.4.5            py35h14c3975_0
# ptyprocess                0.5.2            py35h38ce0a3_0
# py                        1.5.3                    py35_0
# pycodestyle               2.4.0                    py35_0
# pycosat                   0.6.3            py35h6b6bb97_0
# pycparser                 2.18             py35h61b3040_1
# pycrypto                  2.6.1            py35h14c3975_8
# pycurl                    7.43.0.1         py35hb7f436b_0
# pyflakes                  1.6.0            py35hd1da72e_0
# pygments                  2.2.0            py35h0f41973_0
# pylint                    1.8.4                    py35_0
# pyodbc                    4.0.23           py35hf484d3e_0
# pyopenssl                 18.0.0                   py35_0
# pyparsing                 2.2.0            py35h041ed72_1
# pyqt                      5.9.2            py35h751905a_0
# pysimplegui               3.29.0                   pypi_0    pypi
# pysocks                   1.6.8                    py35_0
# pytables                  3.4.3            py35h02b9ad4_2
# pytest                    3.5.1                    py35_0
# pytest-arraydiff          0.2                      py35_0
# pytest-astropy            0.3.0                    py35_0
# pytest-doctestplus        0.1.3                    py35_0
# pytest-openfiles          0.3.0                    py35_0
# pytest-remotedata         0.2.1                    py35_0
# python                    3.5.5                hc3d631a_4
# python-dateutil           2.7.3                    py35_0
# pytz                      2018.4                   py35_0
# pywavelets                0.5.2            py35h53ec731_0
# pyyaml                    3.12             py35h46ef4ae_1
# pyzmq                     17.0.0           py35h14c3975_0
# qt                        5.9.5                h7e424d6_0
# qtawesome                 0.4.4            py35hd68ff89_0
# qtconsole                 4.3.1            py35h4626a06_0
# qtpy                      1.4.1                    py35_0
# readline                  7.0                  ha6073c6_4
# requests                  2.18.4           py35hb9e6ad1_1
# rope                      0.10.7           py35h986144c_0
# ruamel_yaml               0.15.35          py35h14c3975_1
# scikit-image              0.14.0           py35hf484d3e_1
# scikit-learn              0.19.1           py35hbf1f462_0
# scipy                     1.1.0            py35hfc37229_0
# seaborn                   0.8.1            py35h04cba02_0
# send2trash                1.5.0                    py35_0
# setuptools                39.1.0                   py35_0
# simplegeneric             0.8.1                    py35_2
# singledispatch            3.4.0.3          py35h0cd4ec3_0
# sip                       4.19.8           py35hf484d3e_0
# six                       1.11.0           py35h423b573_1
# snappy                    1.1.7                hbae5bb6_3
# snowballstemmer           1.2.1            py35h5435977_0
# sortedcollections         0.6.1                    py35_0
# sortedcontainers          1.5.10                   py35_0
# sphinx                    1.7.4                    py35_0
# sphinxcontrib             1.0              py35hcb7efd2_1
# sphinxcontrib-websupport  1.0.1            py35h3537809_1
# spyder                    3.2.8                    py35_0
# sqlalchemy                1.2.7            py35h6b74fdf_0
# sqlite                    3.23.1               he433501_0
# statsmodels               0.9.0            py35h3010b51_0
# sympy                     1.1.1            py35h919b29a_0
# tblib                     1.3.2            py35hf1eb0b4_0
# tensorboard               1.12.2                   pypi_0    pypi
# tensorflow                1.12.0                   pypi_0    pypi
# tensorflow-gpu            1.0.1                    py35_4
# tensorflow-tensorboard    0.1.8                    pypi_0    pypi
# termcolor                 1.1.0                    py35_1
# terminado                 0.8.1                    py35_1
# testpath                  0.3.1            py35had42eaf_0
# tk                        8.6.7                hc745277_3
# toolz                     0.9.0                    py35_0
# tornado                   5.0.2                    py35_0
# traitlets                 4.3.2            py35ha522a97_0
# typing                    3.6.4                    py35_0
# unicodecsv                0.14.1           py35h4805c0c_0
# unixodbc                  2.3.6                h1bed415_0
# urllib3                   1.22             py35h2ab6e29_0
# wcwidth                   0.1.7            py35hcd08066_0
# webencodings              0.5.1            py35hb6cf162_1
# werkzeug                  0.14.1                   py35_0
# wheel                     0.31.1                   py35_0
# widgetsnbextension        3.2.1                    py35_0
# wrapt                     1.10.11          py35hfdafd39_0
# xlrd                      1.1.0            py35h45a0a2a_1
# xlsxwriter                1.0.4                    py35_0
# xlwt                      1.3.0            py35h884a0cf_0
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zeromq                    4.2.5                h439df22_0
# zict                      0.1.3            py35h29275ca_0
# zlib                      1.2.11               ha838bed_2
